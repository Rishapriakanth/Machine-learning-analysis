# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishapriakanth/Machine-learning-analysis/blob/main/Support_vector_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn import svm
print("Support Vector Regression\n\n")
X,y = make_regression(n_samples=50,n_features=1,noise=0.1,random_state=0)
plt.scatter(X,y, color='green')
plt.title('Regression among X and y')
plt.xlabel('X - axis - X')
plt.ylabel('Y- Dependent - y')
model = svm.SVR(kernel='linear',gamma='auto')
model.fit(X,y)
print('Intercept: \n', model.intercept_)
print('Coefficients: \n', model.coef_)
print('The regression equation is',model.intercept_,'+',model.coef_,'* X')
pred = model.predict(X)
plt.plot(X,pred)
# Out:
# Support Vector Regression
#
#
# Intercept:
#  [0.03619845]
# Coefficients:
#  [[15.81974857]]
# The regression equation is [0.03619845] + [[15.81974857]] * X
